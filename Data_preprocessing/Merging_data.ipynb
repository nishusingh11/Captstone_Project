# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import subprocess as sp

# %%
# !ls /content/drive/MyDrive/BDA600_FinalProject/data/Individual_files
# Out:
#  2000-2023-hawaii.csv   Data_2011-12.csv   Data_2020-21.csv  'query (4).csv'
#  Data_2000-03.csv       Data_2013-14.csv   Data_2022-23.csv  'query (5).csv'
#  Data_2004-07.csv       Data_2015-17.csv  'query (2).csv'    'query (6).csv'
#  Data_2008-10.csv       Data_2018-19.csv  'query (3).csv'

# %%
read_location = '/content/drive/MyDrive/BDA600_FinalProject/data/Individual_files/'
write_location = '/content/drive/MyDrive/BDA600_FinalProject/data/'

files = str(sp.check_output(['ls', read_location])).split('\\n')[:-1]
files[0] = files[0][2:]

print(files)
# Out:
# ['2000-2023-hawaii.csv', 'Data_2000-03.csv', 'Data_2004-07.csv', 'Data_2008-10.csv', 'Data_2011-12.csv', 'Data_2013-14.csv', 'Data_2015-17.csv', 'Data_2018-19.csv', 'Data_2020-21.csv', 'Data_2022-23.csv', 'query (2).csv', 'query (3).csv', 'query (4).csv', 'query (5).csv', 'query (6).csv']

# %%
for i in range(len(files)):
    globals()[f"df_{i}"] = pd.read_csv(read_location+files[i])

# %%
frames = []
frames.extend(value for name, value in locals().items() if name.startswith('df_'))

data = pd.concat(frames) 
print(len(data))
data.head(2)
# Out:
# 100892
#                        time  latitude   longitude  depth   mag magType   nst  \
# 0  2023-02-27T22:58:07.420Z   19.2550 -155.437667   1.15  2.53      ml  42.0
# 1  2023-02-27T17:11:05.500Z   19.4515 -155.236500  28.35  2.74      ml  45.0
#
#      gap  dmin   rms  ...                   updated  \
# 0  111.0   NaN  0.20  ...  2023-02-28T01:54:43.710Z
# 1   71.0   NaN  0.12  ...  2023-02-27T21:24:53.040Z
#
#                          place        type horizontalError depthError  \
# 0    7 km NE of P?hala, Hawaii  earthquake            0.28       0.37
# 1  1 km NNW of Volcano, Hawaii  earthquake            0.42       0.38
#
#    magError  magNst    status  locationSource magSource
# 0  0.117585    23.0  reviewed              hv        hv
# 1  0.252952    22.0  reviewed              hv        hv
#
# [2 rows x 22 columns]

# %%
print(min(data['time']), max(data['time']))
# Out:
# 2000-01-01T03:24:23.217Z 2023-02-27T22:58:07.420Z

# %%
data.to_csv(write_location+'Data_2000-23.csv', index=False)
